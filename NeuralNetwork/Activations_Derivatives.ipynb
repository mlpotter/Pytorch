# %%
import torch
import matplotlib.pyplot as plt

# %%
x = torch.linspace(-10,10,steps=100,dtype=torch.float32,requires_grad=True)

# %% [markdown]
# ## Sigmoid

# %%
y = torch.sigmoid(x)
Y = y.sum()
Y.backward()

# %%
plt.figure(figsize=(20,10))
plt.plot(x.detach().numpy(),y.detach().numpy(),linewidth=5,label="Sigmoid")
plt.plot(x.detach().numpy(),x.grad.numpy(),linewidth=5,label="$\dfrac{dy}{dx}$")
plt.legend(fontsize=20)
plt.xlabel("x",fontsize=30)
plt.ylabel("y",fontsize=30)
plt.title("Sigmoid",fontsize=30)
plt.show()

x.grad.zero_();

# %% [markdown]
# ## tanh

# %%
y = torch.tanh(x)
Y = y.sum()
Y.backward()

# %%
plt.figure(figsize=(20,10))
plt.plot(x.detach().numpy(),y.detach().numpy(),linewidth=5,label="tanh")
plt.plot(x.detach().numpy(),x.grad.numpy(),linewidth=5,label="$\dfrac{dy}{dx}$")
plt.legend(fontsize=20)
plt.xlabel("x",fontsize=30)
plt.ylabel("y",fontsize=30)
plt.title("Sigmoid",fontsize=30)
plt.show()

x.grad.zero_();

# %% [markdown]
# ## ReLu

# %%
y = torch.relu(x)
Y = y.sum()
Y.backward()

# %%
plt.figure(figsize=(20,10))
plt.plot(x.detach().numpy(),y.detach().numpy(),linewidth=5,label="tanh")
plt.plot(x.detach().numpy(),x.grad.numpy(),linewidth=5,label="$\dfrac{dy}{dx}$")
plt.legend(fontsize=20)
plt.xlabel("x",fontsize=30)
plt.ylabel("y",fontsize=30)
plt.title("Sigmoid",fontsize=30)
plt.show()

x.grad.zero_();
